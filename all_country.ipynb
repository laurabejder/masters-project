# %%
# Import pandas, json
import pandas as pd
import json

# %%
#Set max with and display options for pandas
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.width', 1000)

# %%
# Load in the json file natureserve in the data folder
with open('data/natureserve.json') as json_file:
    data = json.load(json_file)

# %%
for d in data:
    if 'speciesGlobal' in d:
        d['taxclass'] = d['speciesGlobal']['taxclass']
        d['taxorder'] = d['speciesGlobal']['taxorder']
    else:
        d['taxclass'] = "NA"
        d['taxorder'] = "NA"

# %%
# Create a list of all the state abbreviations
state_abbreviations = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC","SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
len(state_abbreviations)
# Out:
# 50

# %%
for d in data:
    for nation in d['nations']:
        for states in nation['subnations']:
            # If the subnationCode is in the list of state abbreviations
            name = states['subnationCode']
            key = f"{name}_SRank"
            if states['subnationCode'] in state_abbreviations:
                d[key] = states['roundedSRank']
            else:
                pass
            
            key1 = f"{name}_native"
            if 'native' in states and states['native'] == True and states['subnationCode'] in state_abbreviations:
                d[key1] = True
            elif 'native' in states and states['native'] == False and states['subnationCode'] in state_abbreviations:
                d[key1] = False
            else:
                pass

# %%
# Turn data into a dataframe
df = pd.DataFrame(data)

# %%
df.head(4)
# Out:
#    elementGlobalId                 uniqueId                                             nsxUrl      elcode      scientificName    formattedScientificName         primaryCommonName primaryCommonNameLanguage roundedGRank                                            nations                 lastModified classificationStatus                                      speciesGlobal gRank  taxclass taxorder MI_SRank MI_native OK_SRank OK_native KY_SRank KY_native KS_SRank KS_native NM_SRank NM_native MS_SRank MS_native CO_SRank CO_native IA_SRank IA_native MO_SRank MO_native LA_SRank LA_native WV_SRank WV_native IN_SRank IN_native IL_SRank IL_native AR_SRank AR_native OH_SRank OH_native SD_SRank SD_native MN_SRank MN_native TX_SRank TX_native NE_SRank NE_native WI_SRank WI_native FL_SRank FL_native DE_SRank DE_native GA_SRank GA_native VA_SRank VA_native PA_SRank PA_native NC_SRank NC_native NY_SRank NY_native MD_SRank MD_native NJ_SRank NJ_native AL_SRank AL_native SC_SRank SC_native TN_SRank  \
# 0           828458  ELEMENT_GLOBAL.2.828458    /Taxon/ELEMENT_GLOBAL.2.828458/Acris_blanchardi  AAABC01040    Acris blanchardi    <i>Acris blanchardi</i>  Blanchard's Cricket Frog                        EN           G5  [{'nationCode': 'US', 'roundedNRank': 'N5', 's...  2023-05-06T01:14:26.941215Z             Standard  {'usesaCode': None, 'cosewicCode': 'E', 'saraC...    G5  Amphibia    Anura       S2      True      SNR      True       S5      True       S5      True       S3      True      SNR      True       SH      True       S3      True       S5      True      SNR      True       SH      True       S4      True       S5      True       S5      True       S3      True       S2      True       S1      True       S5      True       S3      True       S1      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN
# 1           828419  ELEMENT_GLOBAL.2.828419     /Taxon/ELEMENT_GLOBAL.2.828419/Acris_crepitans  AAABC01030     Acris crepitans     <i>Acris crepitans</i>      Eastern Cricket Frog                        EN           G5  [{'nationCode': 'US', 'roundedNRank': 'N5', 's...   2023-05-06T01:11:57.91373Z             Standard  {'usesaCode': None, 'cosewicCode': None, 'sara...    G5  Amphibia    Anura      NaN       NaN      NaN       NaN       S5      True      NaN       NaN      NaN       NaN       S5      True      NaN       NaN      NaN       NaN      NaN       NaN       S5      True       S2      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      SNR      True       S5      True       S5      True       S4      True       S1      True       S5      True       S1      True       S5      True       S4      True       S5      True       S5      True       S5
# 2           103292  ELEMENT_GLOBAL.2.103292       /Taxon/ELEMENT_GLOBAL.2.103292/Acris_gryllus  AAABC01020       Acris gryllus       <i>Acris gryllus</i>     Southern Cricket Frog                        EN           G5  [{'nationCode': 'US', 'roundedNRank': 'N5', 's...  2023-05-06T00:07:32.019671Z             Standard  {'usesaCode': None, 'cosewicCode': None, 'sara...    G5  Amphibia    Anura      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN       S5      True      NaN       NaN      NaN       NaN      NaN       NaN       S5      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      SNR      True      NaN       NaN       S5      True       S4      True      NaN       NaN       S5      True      NaN       NaN      NaN       NaN      NaN       NaN       S5      True       S5      True       S2
# 3           100100  ELEMENT_GLOBAL.2.100100  /Taxon/ELEMENT_GLOBAL.2.100100/Ambystoma_barbouri  AAAAA01170  Ambystoma barbouri  <i>Ambystoma barbouri</i>     Streamside Salamander                        EN           G4  [{'nationCode': 'US', 'roundedNRank': 'N4', 's...  2023-05-05T23:55:54.205811Z             Standard  {'usesaCode': 'UR', 'cosewicCode': None, 'sara...    G4  Amphibia  Caudata      NaN       NaN      NaN       NaN       S5      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN       S1      True       S3      True      NaN       NaN      NaN       NaN      SNR      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN       S2
#
#   TN_native RI_SRank RI_native NH_SRank NH_native CT_SRank CT_native VT_SRank VT_native ME_SRank ME_native MA_SRank MA_native MT_SRank MT_native NV_SRank NV_native OR_SRank OR_native UT_SRank UT_native ND_SRank ND_native WA_SRank WA_native HI_SRank HI_native WY_SRank WY_native AZ_SRank AZ_native CA_SRank CA_native ID_SRank ID_native AK_SRank AK_native ecosystemGlobal
# 0       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN             NaN
# 1      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN             NaN
# 2      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN             NaN
# 3      True      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN      NaN       NaN             NaN
